# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Mini Project1 (EDA-Data Preprocessing-Strorytelling and Visualization) </h3>
# </div>

# %% [markdown]
# <img src = "https://www.cyclonis.com/images/2020/03/googleplay.jpg" width=50%>

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load and Prepare Data

# %%
my_data = pd.read_csv('googleplaystore.csv')
my_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## EDA

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
my_data.shape
# Out:
# (10841, 13)

# %%
my_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
my_data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
my_data.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
d = my_data.isnull()
d
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
missing_values = my_data.isnull().sum()
print(missing_values)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
# my_data['Rating'] = my_data['Rating'].fillna(0)

# %%
missing_values = my_data.isnull().sum()
print(missing_values)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
my_data_cleaned = my_data.dropna()

# %%
missing_values_cleaned_data = my_data_cleaned.isnull().sum()
print(missing_values_cleaned_data)
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
my_data_cleaned.shape
# Out:
# (9360, 13)

# %%
type(my_data_cleaned)
# Out:
# pandas.core.frame.DataFrame

# %%
my_data_cleaned
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Strorytelling - Visualization

# %% [markdown]
# Rating counts

# %%
sns.displot(my_data_cleaned, x="Rating",height=20,aspect=1.5  )
# Set the x-axis limit to go up to 6
plt.xlim(1, 5)

# Show the plot
plt.show()

# %%
rating_counts = my_data['Rating'].value_counts()
# print(rating_counts.sum())

# Step 2: Find the group with the most ratings
most_rated_group = rating_counts.idxmax()  # This returns the group name with the most ratings
most_ratings_count = rating_counts.max()  # This gives the number of ratings for that group

# Output the result
print(f"The group with the most ratings is: {most_rated_group} with {most_ratings_count} ratings")
# Out:
# The group with the most ratings is: 4.4 with 1109 ratings

# %%
# rating_counts_withnon = my_data['Category'].value_counts()
# print(rating_counts_withnon )
ing_counts = my_data_cleaned['Category'].value_counts()
print(rating_counts )
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
# Step 1: Drop rows where the Rating is NaN
valid_ratings = my_data_cleaned.dropna(subset=['Rating'])
print(valid_ratings.shape)
# Step 2: Count the number of ratings for each category
rating_counts = valid_ratings['Category'].value_counts()
print(rating_counts)
# Step 3: Find the category with the most ratings
most_rated_category = rating_counts.idxmax()  # This returns the category with the most ratings
most_ratings_count = rating_counts.max()  # This gives the number of ratings for that category

# Output the result
print(f"The category with the most ratings is: {most_rated_category} with {most_ratings_count} ratings")
# Out:
# (9360, 13)
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# ...

# %% [raw]
# get genres for top reviewed apps with rating more than 4.5

# %%
df_cleaned = my_data_cleaned.drop_duplicates(subset='App')
# Filter for apps with rating more than 4.5
filtered_df = df_cleaned [df_cleaned['Rating'] > 4.5]
filtered_df
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
print(filtered_df['Reviews'].dtype)
filtered_df['Reviews'] = pd.to_numeric(filtered_df['Reviews'], errors='coerce')
print(filtered_df['Reviews'].dtype)
# Out:
# int64
# int64

# %%
top_data = filtered_df.sort_values("Reviews", ascending=False )
# top_data = top_data.head(60)
# top_data = top_data[top_data.Rating>4.5]
# sns.displot(top_data, x="Category", height=20,shrink=0.7 )
top_data
# Out:
#                                                     App         Category  \
# 1670                                     Clash of Clans             GAME
# 4005            Clean Master- Space Cleaner & Antivirus            TOOLS
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...            TOOLS
# 1660                                       Clash Royale             GAME
# 4568    360 Security - Free Antivirus, Booster, Cleaner            TOOLS
# ...                                                 ...              ...
# 8335                                      DF Glue Board        PARENTING
# 8287                                AC DC Power Monitor        LIFESTYLE
# 4477                          Android P Style Icon Pack  PERSONALIZATION
# 7623                                        CN Resident           FAMILY
# 2533                                           Zen Leaf          MEDICAL
#
#       Rating   Reviews                Size      Installs  Type  Price  \
# ...

# %%
# Initialize a set to track unique genres
unique_genres = set()
count = 0 
# Initialize an empty list to store the top genres
top_10_unique_genres = []

# Iterate over the rows of the sorted DataFrame
for index, row in top_data.iterrows():
    genre = row['Genres']
    count+=1
    # Add the genre to the set if it is not already there
    if genre not in unique_genres:
        unique_genres.add(genre)
        top_10_unique_genres.append(genre)
        
    
    # Stop when we've found 10 unique genres
    if len(unique_genres) == 10:
        print(count)
        break

# Print out the list of the top 10 unique genres
print(top_10_unique_genres)
# Out:
# 16
# ['Strategy', 'Tools', 'Action', 'Sports', 'Video Players & Editors', 'Arcade', 'Photography', 'Maps & Navigation', 'Personalization', 'Education;Education']

# %%
# Check how many unique genres are present
unique_genres_count = top_data['Genres'].nunique()

print(f"Number of unique genres: {unique_genres_count}")
# Out:
# Number of unique genres: 75

# %%
top_data_100=top_data.head(100)
top_data_100["Genres"].value_counts()
# Out:
# Tools                      12
# Action                      9
# Photography                 8
# Casual                      7
# Personalization             6
# Strategy                    5
# Puzzle                      5
# Productivity                5
# Video Players & Editors     4
# Communication               4
# Books & Reference           4
# Shopping                    4
# Entertainment               3
# Social                      3
# Sports                      3
# Health & Fitness            2
# Racing                      2
# Role Playing                2
# Arcade                      2
# Lifestyle                   2
# Education;Education         1
# Simulation                  1
# Maps & Navigation           1
# Travel & Local              1
# Finance                     1
# Card                        1
# Education                   1
# Food & Drink                1
# Name: Genres, dtype: int64

# %%
# Create your displot
# sns.set_theme(style="ticks", color_codes=True,font_scale=1.3)
g = sns.displot(top_data_100, x="Genres", height=20, aspect=1.5)
plt.xticks(rotation=90)
# Set the font size for specific elements
g.set_axis_labels("Genres", "Frequency", fontsize=22)  # Axis labels
g.fig.suptitle("Distribution of Genres", fontsize=22)  # Title
g.set_xticklabels(g.ax.get_xticklabels(), fontsize=24)  # X-axis tick labels
g.set_yticklabels(g.ax.get_yticklabels(), fontsize=26)  # Y-axis tick labels

# Show the plot
plt.show()

# %% [markdown]
# displot of rating base on age of raters

# %%
sns.displot(my_data, x="Rating",hue='Content Rating',height=20, kind="kde")

# %% [markdown]
# arange based on rating

# %%
print(filtered_df['Rating'].dtype)
# Out:
# float64

# %%
my_data.sort_values( 'Rating',ascending=False)
# Out:
#                                            App             Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                  1.9    19.0
# 9511                  Ek Bander Ne Kholi Dukan               FAMILY     5.0
# 10166                     FA Player Essentials               SPORTS     5.0
# 7895                Dine In CT - Food Delivery             SHOPPING     5.0
# 5118                          Eternal Light AG               SOCIAL     5.0
# ...                                        ...                  ...     ...
# 10824                                Cardio-FR              MEDICAL     NaN
# 10825                       Naruto & Boruto FR               SOCIAL     NaN
# 10831                 payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                 FR Forms             BUSINESS     NaN
# 10838                   Parkinson Exercices FR              MEDICAL     NaN
#
# ...

# %%
data = my_data_cleaned.sort_values( 'Installs',ascending=False)
data
# Out:
#                                App       Category  Rating   Reviews  \
# 474    LINE: Free Calls & Messages  COMMUNICATION     4.2  10790289
# 1759                  Temple Run 2           GAME     4.3   8118937
# 1722                My Talking Tom           GAME     4.5  14891223
# 3562               Google Calendar   PRODUCTIVITY     4.2    858230
# 1729                  Temple Run 2           GAME     4.3   8118937
# ...                            ...            ...     ...       ...
# 2170                     Hactar Go         FAMILY     4.8        97
# 6740                  B@dL!bs Lite           GAME     3.8        10
# 2454           KBA-EZ Health Guide        MEDICAL     5.0         4
# 10697                      Mu.F.O.           GAME     5.0         2
# 5917                      Ra Ga Ba           GAME     5.0         2
#
#                      Size      Installs  Type  Price Content Rating  \
# 474    Varies with device  500,000,000+  Free      0       Everyone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and contains columns 'Genres' and 'Type'
r = sns.displot(y="Genres", height=18, data=data, hue="Type", aspect=0.8)  # Adjusted height for better readability

# Set the font size for specific elements
r.set_axis_labels("Genres", "Distribution of Genres", fontsize=22)  # Axis labels
r.fig.suptitle("Frequency", fontsize=22)  # Title

# Adjust the legend font size (Text and Title)
# Access the legend via r.axes[0, 0] for the first axes in the FacetGrid
legend = r.axes[0, 0].get_legend()



# Show the plot
plt.show()

# %%
sns.catplot(x="Installs", y="Rating",height=20, data=my_data.head(5000), kind="boxen", aspect=1)
